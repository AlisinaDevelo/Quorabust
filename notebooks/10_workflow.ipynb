# %% [markdown]
# # Quorabust workflow
#
# 1. Download [Quora Question Pairs](https://www.kaggle.com/c/quora-question-pairs) `train.csv` into `data/raw/`.
# 2. From the repository root (with the venv activated):
#
# ```bash
# quorabust-train --csv data/raw/train.csv --out models/quorabust.pkl
# ```
#
# Use `--max-rows` for a quick subset and `--eval-fraction 0` to skip the holdout split.
#
# 3. Load the artifact in Python:
#
# ```python
# from quorabust import load_classifier, predict_proba_duplicate
# builder, clf, meta = load_classifier("models/quorabust.pkl")
# predict_proba_duplicate(builder, clf, ["How do I sort a list?"], ["Python list sort?"])
# ```

# %%
from quorabust import clean_text

clean_text("  Hello   WORLD!!  ")
